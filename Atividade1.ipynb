# %%
import pandas as pd

# %%
tabela = pd.read_csv(r"C:\Users\Lucas Cruz\Downloads\MICRODADOS.csv", encoding='latin-1', sep=";", low_memory=False)
tabela.head()
# Out:
#   DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 0      2023-04-02   2023-04-02      2023-04-02               NaN
# 1      2023-04-02   2023-04-02      2023-03-31               NaN
# 2      2023-04-02   2023-04-02      2023-04-02               NaN
# 3      2023-04-02   2023-04-02      2023-03-31               NaN
# 4      2023-04-02   2023-04-02      2023-04-02               NaN
#
#   DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# 0            2023-04-02                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2            2023-04-02                 NaN                    NaN
# 3            2023-04-02                 NaN                    NaN
# 4            2023-04-02                 NaN                    NaN
#
#   DataEncerramento DataObito Classificacao  ... ViagemBrasil  \
# 0       2023-04-02       NaN   Descartados  ...          Não
# ...

# %%
query = tabela.query('Municipio == "CARIACICA" & ComorbidadeTabagismo == "Sim" & DataObito > "2019" & Evolucao == "Óbito pelo COVID-19"').dropna(subset=['DataObito'])
query[['Municipio', 'ComorbidadeTabagismo', 'DataObito', 'Evolucao']]
# Out:
#          Municipio ComorbidadeTabagismo   DataObito             Evolucao
# 128813   CARIACICA                  Sim  2023-01-10  Óbito pelo COVID-19
# 700227   CARIACICA                  Sim  2022-07-14  Óbito pelo COVID-19
# 820934   CARIACICA                  Sim  2022-01-23  Óbito pelo COVID-19
# 828824   CARIACICA                  Sim  2022-07-15  Óbito pelo COVID-19
# 988058   CARIACICA                  Sim  2022-06-29  Óbito pelo COVID-19
# ...            ...                  ...         ...                  ...
# 4739463  CARIACICA                  Sim  2020-06-19  Óbito pelo COVID-19
# 4740626  CARIACICA                  Sim  2020-05-08  Óbito pelo COVID-19
# 4745414  CARIACICA                  Sim  2020-05-10  Óbito pelo COVID-19
# 4745541  CARIACICA                  Sim  2020-05-05  Óbito pelo COVID-19
# 4755674  CARIACICA                  Sim  2020-04-21  Óbito pelo COVID-19
#
# [73 rows x 4 columns]
